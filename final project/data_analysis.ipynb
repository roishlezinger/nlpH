# %%
import plotly.offline as py
import plotly.graph_objects as go
import networkx as nx
# %run organizes_data.ipynb
# Out:
# Can't extract Name121,9
# Can't extract Name361,11
# # 0
# # 100
# # 200
# # 300
# # 400
# # 500
# # 600
# # 700
# # 800
# # 900
# # 1000
# # 1100
# # 1200
# # 1300
# # 0
# # 100
# # 200
# # 300
# # 400
# # 500
# # 600
# # 700
# # 800
# # 900
# # 1000
# # 1100
# # 1200
# # 1300
# <>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <>:26: DeprecationWarning:
#
# invalid escape sequence \d
#
# <>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <>:26: DeprecationWarning:
#
# invalid escape sequence \d
#
# <ipython-input-70-ffcbda2cf765>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <ipython-input-70-ffcbda2cf765>:26: DeprecationWarning:
#
# invalid escape sequence \S
#
# <ipython-input-70-ffcbda2cf765>:26: DeprecationWarning:
#
# invalid escape sequence \d

# %% [markdown]
# ## LDA

# %%
import gensim
import pyLDAvis.gensim


def get_lda_objects(text):

    corpus= text
    dic=gensim.corpora.Dictionary(corpus)
    bow_corpus = [dic.doc2bow(doc) for doc in corpus]

    lda_model =  gensim.models.LdaMulticore(bow_corpus,num_topics = 6,
                                   id2word = dic,
                                   passes = 10,
                                   workers = 2)

    return lda_model, bow_corpus, dic

def plot_lda_vis(lda_model, bow_corpus, dic):
    pyLDAvis.enable_notebook()
    vis = pyLDAvis.gensim.prepare(lda_model, bow_corpus, dic)
    return vis

# %%
lda_model, bow_corpus, dic = get_lda_objects([temp])
lda_model.show_topics()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-c66989aac1d1> in <module>
# ----> 1 lda_model, bow_corpus, dic = get_lda_objects([temp])
#       2 lda_model.show_topics()
#       3
#       4
#
# <ipython-input-39-473320a09e81> in get_lda_objects(text)
#       8     #dic=gensim.corpora.Dictionary(corpus)
#       9     dic = corpus
# ---> 10     bow_corpus = [dic.doc2bow(doc) for doc in corpus]
#      11
#      12     lda_model =  gensim.models.LdaMulticore(bow_corpus,num_topics = 6,
#
# <ipython-input-39-473320a09e81> in <listcomp>(.0)
#       8     #dic=gensim.corpora.Dictionary(corpus)
#       9     dic = corpus
# ---> 10     bow_corpus = [dic.doc2bow(doc) for doc in corpus]
#      11
#      12     lda_model =  gensim.models.LdaMulticore(bow_corpus,num_topics = 6,
#
# AttributeError: 'list' object has no attribute 'doc2bow'

# %%
import gensim.corpora as corpora
id2word = corpora.Dictionary([joy_lemma])
print(id2word)
texts = [joy_lemma]
corpus = [id2word.doc2bow(text) for text in texts]
print(corpus[:1])

# %%
id2word[13]
# Out:
# '!אבל'

# %% [markdown]
# ## Network Graph
# לחפש בגוגל:
#
# network graph nlp python

# %%
text = temp
n = 2
vec = CountVectorizer(ngram_range=(n, n)).fit(text)
bag_of_words = vec.transform(text)
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx])
              for word, idx in vec.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
words_freq = words_freq[:20]

# %%
print(words_freq)
